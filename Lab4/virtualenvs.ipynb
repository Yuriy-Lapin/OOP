# %% [markdown]
# ### Статус код

# %%
import requests

res = requests.get('https://google.com')
print(res.status_code)
# Out:
# 200

# %% [markdown]
# ### Перевірка зв'язку на requests

# %%
import requests


def check_inet(link='https://google.com'):
    res = requests.get(link)
    if res.status_code == 200:
        print(f'Ststus - {res.status_code}')
    else:
        print(f'Ststus - {res.status_code}')

check_inet()
# Out:
# Ststus - 200

# %% [markdown]
# ### Ще забавки з рекюестс

# %%
import requests as r

res = r.get('https://api.github.com/events')

print(f'''
url \t {res.url}
just res \t {res}
status code \t {res.status_code}
encoding \t {res.encoding}
raw \t {res.raw}
a lot of text \t {res.text}
''')
# Out:
# url 	 https://api.github.com/events
# just res 	 <Response [200]>
# status code 	 200
# encoding 	 utf-8
# raw 	 <urllib3.response.HTTPResponse object at 0x000001B1E2B52890>
# ...

# %% [markdown]
# Декоратори

# %%
def sqrt(x):
    return x**2

@sqrt
def sqrt2(x):
    return x**2


print(sqrt2(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Labs\Labs 3.1\ООП\github\OOP\Lab4\virtualenvs.ipynb Cell 8 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Labs/Labs%203.1/%D0%9E%D0%9E%D0%9F/github/OOP/Lab4/virtualenvs.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> def sqrt(x):
#       <a href='vscode-notebook-cell:/d%3A/Labs/Labs%203.1/%D0%9E%D0%9E%D0%9F/github/OOP/Lab4/virtualenvs.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     return x**2
#       <a href='vscode-notebook-cell:/d%3A/Labs/Labs%203.1/%D0%9E%D0%9E%D0%9F/github/OOP/Lab4/virtualenvs.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> @sqrt
# ----> <a href='vscode-notebook-cell:/d%3A/Labs/Labs%203.1/%D0%9E%D0%9E%D0%9F/github/OOP/Lab4/virtualenvs.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> def sqrt2(x):
# ...
